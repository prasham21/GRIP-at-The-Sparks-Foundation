# %% [markdown]
# ## Task 4

# %% [markdown]
# #### Creating a Decision Tree Classifier for the Iris dataset

# %% [markdown]
# ### Importing Libraries and Loading Dataset

# %%
# Importing libraries in Python
import sklearn.datasets as datasets
import pandas as pd

# Loading the iris dataset
iris=datasets.load_iris()

# Forming the iris dataframe
df=pd.DataFrame(iris.data, columns=iris.feature_names)
print(df.head(5))

y=iris.target
print(y)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %% [markdown]
# ### Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
from adspy_shared_utilities import plot_decision_tree
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state = 3)
clf = DecisionTreeClassifier().fit(X_train, y_train)

# %% [markdown]
# ### Visualising the Dataset

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")
g = sns.pairplot(iris, hue="species")

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(80,55.5))
plot_tree(clf,filled=True,rounded=True,feature_names=iris.feature_names)
# Out:
# [Text(1785.6, 2765.565, 'petal width (cm) <= 0.8\ngini = 0.666\nsamples = 112\nvalue = [35, 38, 39]'),
#  Text(1339.1999999999998, 2262.735, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(2232.0, 2262.735, 'petal width (cm) <= 1.65\ngini = 0.5\nsamples = 77\nvalue = [0, 38, 39]'),
#  Text(892.8, 1759.905, 'petal length (cm) <= 4.95\ngini = 0.139\nsamples = 40\nvalue = [0, 37, 3]'),
#  Text(446.4, 1257.075, 'gini = 0.0\nsamples = 36\nvalue = [0, 36, 0]'),
#  Text(1339.1999999999998, 1257.075, 'sepal width (cm) <= 2.75\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 3]'),
#  Text(892.8, 754.2449999999999, 'petal width (cm) <= 1.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(446.4, 251.41499999999996, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(1339.1999999999998, 251.41499999999996, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(1785.6, 754.2449999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(3571.2, 1759.905, 'petal length (cm) <= 4.85\ngini = 0.053\nsamples = 37\nvalue = [0, 1, 36]'),
#  Text(3124.7999999999997, 1257.075, 'sepal width (cm) <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(2678.3999999999996, 754.2449999999999, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(3571.2, 754.2449999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(4017.6, 1257.075, 'gini = 0.0\nsamples = 34\nvalue = [0, 0, 34]')]

# %% [markdown]
# ### Evaluation Metrics

# %%
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# Accuracy of Decision Tree classifier on training set: 1.00
# Accuracy of Decision Tree classifier on test set: 0.95
